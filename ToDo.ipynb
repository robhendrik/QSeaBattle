# %% [markdown]
# To do
#
# [x] check all tests and make sure all pass
# [x] at set_* to SR layer
# [x] at set_* to models in WIP
# [x] Test for regression and new functionality
# [x] test training script to go to 100% from scratch
# [x] test training script to run down p_high
# [x] test tournament with trained models for gameplay interaction
# [] remove trainable models from main src, incl documentation
# [] remove tests related to these models
# [] move WIP src to main
# [] move tests form WIP to main
# [] move training script to main and test
# [] add tests for training scripts
# [] test tournament on trianed models
# [] rename variables in sr layer/models
# [] add comms output to a, execute consistently to keep tests ok
# [] create generic model
# [] create generic model dataset
# [] trian generic model
# [] create linear model
# [] create linear model dataset
# [] train linear model
# [] update documentation
