# %% [markdown]
# To do
#
# [x] Documentation Game, Game env game layout and base players
# [x] Documentation for Tournament and TournamentLog
# [x] correct naming error PlayerSA and PlayerSB, correct fileciteturn5file0
# [x] Documentation for simple and majiroty players
# [x] Documentation for neural net players
# [x] find name for shared randomness
#
# -- mini project
# [x] Create modules woth new names for assisted players (3x)
# [x] Create wrappers for the old ones
# [x] Move olde ones to archive
# [x] update init.py
# [x] create an run tests with new names
# [x] update tutorials to reflect new names
# [x] create mkdocs markdowns to players (3x) and new shared randomness (1x)
# [x] Create mkdocs for naming logic resources
# -- End mini project
#
# -- mini project
# [x] rename shared randomness layer
# [x] add test to tests
# [x] update md in mkdocs
# [x] update init.py to new name for layer
# [x] make old layer a stub with a warning
#
# [] Documentation for reference performance utilities
# [] including algorithm for simple and majority in algo section and check consistency
# [] Documentation for DRU/DIAl and logit utilities
# [] check information theoretical limits, log plotting for video and add MD with math and references
# [] Check conventions and invariants
#
#
# --- Everything done except for trainable assisted players
# [] add assisted player 'pyr' algo to algorithms with proper name for PR assisted
# [] add assisted player 'lin' algo to algorithms with proper name for PR assisted
#
# [] lin trainable models to new layer name, move old to archive
# [] pyr trainanle models to new layer name,  move old to archive
# [] lin imitation tutorial to new name
# [] pyr imitation tutorial to new name
# [] test for both models with new name
# [] mk docs for lin model and players
# [] mk docs for pyr model and players
# --- trianable shared models updtaes
