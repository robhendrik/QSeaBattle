# %% [markdown]
# To do
#
# [x] Documentation Game, Game env game layout and base players
# [x] Documentation for Tournament and TournamentLog
# [x] correct naming error PlayerSA and PlayerSB, correct fileciteturn5file0
# [x] Documentation for simple and majiroty players
# [] Documentation for reference performance utilities
# [] including algorithm for simple and majority in algo section and check consistency
# [] Documentation for neural net players
# [] Documentation for DRU/DIAl and logit utilities
# [] check information theoretical limits, log plotting for video and add MD with math and references
# [] Check conventions and invariants
# [] find name for shared randomness
# [] shared randomness utils
# [] check assisted player spec vs implementation & chaneg name to indicate pyr algo
# [] add lin assisted player to spec and implementation, including algo and test cases
# [] md for dru utils and logit utils neural net imitation utils
# [] md for reference performance utils
# [] check and adapt tutorial for WSG, imitation and DIAl/DRU
#
# --- Everything done except for trainable assisted players
#
# [] add assisted player 'pyr' algo to algorithms
# []
# []
# [] Check neura; net implementation vs MD
# [] Add section on dial to MD
# [] lin trainable models
# [] pyr trainanle models
